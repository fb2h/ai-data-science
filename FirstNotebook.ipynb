# %% [markdown]
# <a href="https://colab.research.google.com/github/fb2h/ai-data-science/blob/main/FirstNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ask the student to enter their name

# %%
name = input("What is your name?")
# Out:
# What is your name?Ryan

# %%
scores = [85,90,95]
Average=sum(scores)/len(scores)
print("Hello", name)
print("Your average score is:", Average)
# Out:
# Hello Ryan
# Your average score is: 90.0
